# %%
x = 5
print(x)
# Out:
# 5

# %%
x = 1000
print(x)
# Out:
# 1000

# %%
savings = 1000
factor = 1.1
result = savings * factor ** 15
print(result)
# Out:
# 4177.248169415656

# %%
desc = 'Data Science'
profitable = True

# %%
a = 10
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(savings))
print(type(factor))
print(type(desc))
print(type(profitable))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
savings = 1000
factor = 1.10
desc = "Data Science"
year1 = savings * factor
print(type(year1))
doubledesc = desc * 2
print(doubledesc)
# Out:
# <class 'float'>
# Data ScienceData Science

# %%
savings = 1000
result = 1000 * 1.10 ** 15
print("Tôi gửi ngân hàng $" + str(savings) +", sau 15 năm, bây giờ tôi đã có $" + str(result) + ". Tuyệt vời!")
pi_string = "3.1415926"
pi_float = float(pi_string)
# Out:
# Tôi gửi ngân hàng $1000, sau 15 năm, bây giờ tôi đã có $4177.248169415656. Tuyệt vời!

# %%
hall = 11.25
kit = 18.0
liv = 20.0
bed = 10.75
bath = 9.50
areas = [hall, kit, liv, bed, bath]
print(areas)
# Out:
# [11.25, 18.0, 20.0, 10.75, 9.5]

# %%
hall = 11.25
kit = 18.0
liv = 20.0
bed = 10.75
bath = 9.50
arreas = [hall, kit, "living room", liv, bed, "bathroom", bath]
print(areas)
# Out:
# [11.25, 18.0, 20.0, 10.75, 9.5]

# %%
hall = 11.25
kit = 18.0
liv = 20.0
bed = 10.75
bath = 9.50
house = [["hallway", hall],
         ["kitchen", kit],
         ["living room", liv]]
print(house)
print(type(house))
# Out:
# [['hallway', 11.25], ['kitchen', 18.0], ['living room', 20.0]]
# <class 'list'>

# %%
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 10.75, "bathroom", 9.50]
print(areas[1])
print(areas[-1])
print(areas[5])
# Out:
# 11.25
# 9.5
# 10.75

# %%
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]
eat_sleep_area = areas[3] + areas[-3]
print(eat_sleep_area)
# Out:
# 28.75

# %%
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]
downstairs = areas[0:6]
upstairs = areas[6:-1]
print(downstairs)
print(upstairs)
# Out:
# ['hallway', 11.25, 'kitchen', 18.0, 'living room', 20.0]
# ['bedroom', 10.75, 'bathroom']

# %%
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]
downstairs = areas[:6]
upstairs = areas[6:]
print(downstairs)
print(upstairs)
# Out:
# ['hallway', 11.25, 'kitchen', 18.0, 'living room', 20.0]
# ['bedroom', 10.75, 'bathroom', 9.5]

# %%
x = [["a", "b", "c"],
     ["d", "e", "f"],
     ["g", "h", "i"]]
x[2][0]
x[2][:2]
# Out:
# ['g', 'h']
